# %% [markdown]
# Guideline parsing

# %% [markdown]
# First of all, we must prepare the environment installing the required packages.

# %%
# %pip install beautifulsoup4 bs4 requests pathvalidate cleantext
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (4.12.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: bs4 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (0.0.2)
# Requirement already satisfied: requests in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: pathvalidate in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (3.2.1)
# Requirement already satisfied: cleantext in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (1.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: nltk in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from cleantext) (3.9.1)
# Requirement already satisfied: click in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from nltk->cleantext) (8.1.7)
# Requirement already satisfied: joblib in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from nltk->cleantext) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from nltk->cleantext) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from nltk->cleantext) (4.66.5)
# Requirement already satisfied: colorama in c:\users\jhyra\programmazione\llm\urology_rag\.venv\lib\site-packages (from click->nltk->cleantext) (0.4.6)

# %% [markdown]
# Then, we are going to download the first page of the guidelines and parse it to extract the name of all the guidelines.

# %%
from bs4 import BeautifulSoup
import requests

website_root = "https://uroweb.org" #Guidelines domain
folder_guidelines_root = "/guidelines"  #Guidelines page
guidelines_url = website_root + folder_guidelines_root
html_document = requests.get(guidelines_url).text #Webpage downloader, output as json
guidelines_index_soup = BeautifulSoup(html_document, 'html.parser') #Creation of a "soup" object, make easier to navigate the document
all_guidelines_a_class = guidelines_index_soup.findAll("a", {"class": "guideline-card"}) #Find all link that have the word 'guidelines' inside

#Enumerating the guidelines found
all_guidelines_url = []
for guideline in all_guidelines_a_class:
    all_guidelines_url.append(guideline['href'])
    print(guideline['href'])
# Out:
# /guidelines/prostate-cancer
# /guidelines/non-muscle-invasive-bladder-cancer
# /guidelines/upper-urinary-tract-urothelial-cell-carcinoma
# /guidelines/muscle-invasive-and-metastatic-bladder-cancer
# /guidelines/primary-urethral-carcinoma
# /guidelines/renal-cell-carcinoma
# /guidelines/testicular-cancer
# /guidelines/penile-cancer
# /guidelines/sexual-and-reproductive-health
# /guidelines/non-neurogenic-female-luts
# /guidelines/urethral-strictures
# /guidelines/management-of-non-neurogenic-male-luts
# /guidelines/chronic-pelvic-pain
# /guidelines/urological-infections
# /guidelines/neuro-urology
# /guidelines/urolithiasis
# /guidelines/paediatric-urology
# /guidelines/urological-trauma
# /guidelines/renal-transplantation

# %% [markdown]
# To proper indexing and vectorializing, it would be better to not randomly split the text, but to subdivide it.
# We can do this by splitting the pragraph categorized using an h* token.
# We can perform this recursivly until each file is under our desired lenght
#
# In the following cell, we are going to declare the funcion to perfom the split and declare the variables that regulate the split

# %%
import os
from pathvalidate import sanitize_filename

#May be worth noticing that if you already have a model running, you can use their tokenizer function to get the real amount of tokens
# This works on llama.cpp, different inference software may have different methods
## len(llm_model.tokenize(bytes("This is a test", encoding='utf-8')))

#We start from <h4> because <h3> are the chapters titles
def h4_splitter(
        full_paragraph_raw,
        chapter_folder_path,
        token_subdivider,
        maximum_token_lenght,
        ):
    header_list = ['h3', 'h4']  #Target headers for this split cycle
    file_path = os.path.join(
        chapter_folder_path, #Chapter folder path from function argument
        sanitize_filename(full_paragraph_raw[0].text.replace(" ", "_").lower()[:15]) #Sanitized filename cut to the first 15 characters
        )
    os.makedirs(file_path, exist_ok=True)
    #We must initialize the variables for the loop
    paragraph_loop = 0   #variable to check if we are going to populate the subparagraph of another header
    full_sub_paragraph_raw = [] #Subpragraph list
    full_paragraph_txt = "" #Subparagraph text
    #Iterating on each row of the paragraph
    for row in full_paragraph_raw:
        #If this row and the next one have consecutives target headers, skip this row
        if row.name in header_list and row.find_next_sibling().name in header_list:
            continue
        #If this row and the next one does not have consecutives target headers, proceed
        if row.name in header_list and row.find_next_sibling().name not in header_list:
            #If there is a loop in progress, we must check if we need to split the paragraph or if we can save the file
            if paragraph_loop == 1:
                text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
                if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
                    #All these print are for debug purposes, you can remove them
                    print("Split to h5")
                    print("File: " + filename_sanitized)
                    print("Lenght: " + str(text_tokens))
                    print ("")
                    h5_splitter(full_sub_paragraph_raw, file_path, token_subdivider, maximum_token_lenght)  #We call the next split function
                    #We reset the variables for a new loop/file
                    full_paragraph_txt = ""
                    full_sub_paragraph_raw = []
                    paragraph_loop = 0
                else:   #If the token count is lower than the maximum lenght, we save the file
                    f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
                    f.write(full_paragraph_txt)    #Write the variable on the file
                    f.close()   #Close the file
                    #We reset the variables for a new loop/file
                    full_paragraph_txt = ""
                    full_sub_paragraph_raw = []
                    paragraph_loop = 0
            #If there is no loop in progress, we must define the new filename
            if paragraph_loop == 0:
                full_paragraph_txt += row.text + ". " #We append a dot and a space at the end of the row
                full_sub_paragraph_raw.append(row)  #We add the header and separate it from the rest of the text
                filename_sanitized = sanitize_filename(row.text.replace(" ", "_").lower()[:25] + ".txt") #We sanitize the filename and cut it to the first 25 characters
                paragraph_loop = 1   #We set that we are in a loop to populate a subparagraph
        #If the row has not a target header, we add the text to the subparagraph
        if row.name not in header_list:
            full_paragraph_txt += row.text + " " #We append a space at the end of the row
            full_sub_paragraph_raw.append(row) #We add the paragraph to the full text
    #At the end of the for, we must save the last paragraph and reset the variables
    text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
    if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
        #All these print are for debug purposes, you can remove them
        print("Split to h5")
        print("File: " + filename_sanitized)
        print("Lenght: " + str(text_tokens))
        print ("")
        h5_splitter(full_sub_paragraph_raw, file_path, token_subdivider, maximum_token_lenght) #We call the next split function
    else:   #If the token count is lower than the maximum lenght, we save the file
        f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
        f.write(full_paragraph_txt)    #Write the variable on the file
        f.close()   #Close the file

def h5_splitter(
        full_paragraph_raw,
        chapter_folder_path,
        token_subdivider,
        maximum_token_lenght,
        ):
    header_list = ['h3', 'h4', 'h5']    #Target headers for this split cycle
    file_path = os.path.join(chapter_folder_path, sanitize_filename(full_paragraph_raw[0].text.replace(" ", "_").lower()[:15])) #Chapter folder path from function argument
    os.makedirs(file_path, exist_ok=True)   #Create the folder if it doesn't exist
    #We must initialize the variables for the loop
    paragraph_loop = 0
    full_sub_paragraph_raw = []
    full_paragraph_txt = ""
    #Iterating on each row of the paragraph
    for row in full_paragraph_raw:
        #If this row and the next one have consecutives target headers, skip this row
        if row.name in header_list and row.find_next_sibling().name in header_list:
            continue
        #If this row and the next one does not have consecutives target headers, proceed
        if row.name in header_list and row.find_next_sibling().name not in header_list:
            #If there is a loop in progress, we must check if we need to split the paragraph or if we can save the file
            if paragraph_loop == 1:
                text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
                if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
                    #All these print are for debug purposes, you can remove them
                    print("Split to h6")
                    print("File: " + filename_sanitized)
                    print("Lenght: " + str(text_tokens))
                    print ("")
                    h6_splitter(full_sub_paragraph_raw, file_path, token_subdivider, maximum_token_lenght)  #We call the next split function
                    #We reset the variables for a new loop/file     
                    full_paragraph_txt = ""
                    full_sub_paragraph_raw = []
                    paragraph_loop = 0
                else:   #If the token count is lower than the maximum lenght, we save the file
                    f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
                    f.write(full_paragraph_txt)    #Write the variable on the file
                    f.close()   #Close the file
                    #We reset the variables for a new loop/file
                    full_paragraph_txt = ""
                    full_sub_paragraph_raw = []
                    paragraph_loop = 0
            #If there is no loop in progress, we must define the new filename
            if paragraph_loop == 0:
                full_paragraph_txt += row.text + ". "   #We append a dot and a space at the end of the row
                full_sub_paragraph_raw.append(row)  #We add the header and separate it from the rest of the text
                filename_sanitized = sanitize_filename(row.text.replace(" ", "_").lower()[:25] + ".txt") #We sanitize the filename and cut it to the first 25 characters
                paragraph_loop = 1   #We set that we are in a loop to populate a subparagraph
        #If the row has not a target header, we add the text to the subparagraph
        if row.name not in header_list:
            full_paragraph_txt += row.text + " "    #We append a space at the end of the row
            full_sub_paragraph_raw.append(row)      #We add the paragraph to the full text
    #At the end of the for, we must save the last paragraph and reset the variables
    text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
    if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
        #All these print are for debug purposes, you can remove them
        print("Split to h6")
        print("File: " + filename_sanitized)
        print("Lenght: " + str(text_tokens))
        print ("")
        h6_splitter(full_sub_paragraph_raw, file_path, token_subdivider, maximum_token_lenght)  #We call the next split function
    else:   #If the token count is lower than the maximum lenght, we save the file
        f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
        f.write(full_paragraph_txt)    #Write the variable on the file
        f.close()   #Close the file

def h6_splitter(
        full_paragraph_raw,
        chapter_folder_path,
        token_subdivider,
        maximum_token_lenght,
        ):
    header_list = ['h3', 'h4', 'h5', 'h6']  #Target headers for this split cycle
    file_path = os.path.join(chapter_folder_path, sanitize_filename(full_paragraph_raw[0].text.replace(" ", "_").lower()[:15])) #Chapter folder path from function argument
    os.makedirs(file_path, exist_ok=True)   #Create the folder if it doesn't exist
    #We must initialize the variables for the loop
    paragraph_loop = 0
    full_sub_paragraph_raw = []
    full_paragraph_txt = ""
    #Iterating on each row of the paragraph
    for row in full_paragraph_raw:
        #If this row and the next one have consecutives target headers, skip this row
        if row.name in header_list and row.find_next_sibling().name in header_list:
            continue
        #If this row and the next one does not have consecutives target headers, proceed
        if row.name in header_list and row.find_next_sibling().name not in header_list:
            #If there is a loop in progress, we must check if we need to split the paragraph or if we can save the file
            if paragraph_loop == 1:
                text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
                if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
                    #All these print are for debug purposes, you can remove them
                    print("Still too long..." + str(text_tokens))
                    print("Proceding to half split")
                    print ("")
                    print(filename_sanitized)
                    #Since <h6> is the smallest paragraph I found, to further reduce the lenght we split the paragraph in half
                    splitted_string = split_string_in_half(full_paragraph_txt)  #We split the paragraph in half
                    i1 = 1  #We initialize the counter for the first split
                    #Iterating on the splitted string
                    for split in splitted_string:
                        text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
                        if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
                            #All these print are for debug purposes, you can remove them
                            print("Still still too long..." + str(text_tokens))
                            print("Proceding to second half split")
                            print ("")
                            print(filename_sanitized)
                            #If the paragraph is still too long, we split it again
                            splitted_string2 = split_string_in_half(split)
                            i2 = 1  #We initialize the counter for the second split
                            #Iterating on the second splitted string
                            for split2 in splitted_string2:
                                #We do not proceed to further split the file, we save it
                                #We could actually proceed to further split the file, but it's not necessary for the purpose of this script
                                #In case we need to iterative and endlessy split the file it would be better to implement a recursive function
                                #Still, blindly splitting may lead to loss of context and meaning, so a manual check is always recommended and if a ton of splitting is needed, maybe consider using a model with bigger context window or implement a semantic splitting
                                f = open(os.path.join(file_path,filename_sanitized.replace(".txt", "")+"-"+str(i1)+"-"+str(i2)+".txt"), "w", encoding="utf-8")  #Create/open the file
                                f.write(split2)    #Write the variable on the file
                                f.close()   #Close the file
                                i2 += 1   #Increment the counter for the second split
                        else:
                            f = open(os.path.join(file_path,filename_sanitized.replace(".txt", "")+"-"+str(i1)+".txt"), "w", encoding="utf-8")  #Create/open the file
                            f.write(split)  #Write the variable on the file
                            f.close()   #Close the file
                            i1 += 1  #Increment the counter for the first split
                else:
                    #Make a subchapter folder, and create it if it doesn't exist
                    file_path = os.path.join(chapter_folder_path, sanitize_filename(full_paragraph_raw[0].text.replace(" ", "_").lower()[:15])) #Chapter folder path from function argument
                    os.makedirs(file_path, exist_ok=True)   #Create the folder if it doesn't exist
                    f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
                    f.write(full_paragraph_txt)    #Write the variable on the file
                    f.close()   #Close the file
                    #We reset the variables for a new loop/file
                    full_paragraph_txt = ""
                    full_sub_paragraph_raw = []
                    paragraph_loop = 0
            #If there is no loop in progress, we must define the new filename
            if paragraph_loop == 0:
                full_paragraph_txt += row.text + ". "   #We append a dot and a space at the end of the row
                full_sub_paragraph_raw.append(row)  #We append the row to the full text
                filename_sanitized = sanitize_filename(row.text.replace(" ", "_").lower()[:25] + ".txt")    #We sanitize the filename and cut it to the first 25 characters
                paragraph_loop = 1   #We set that we are in a loop to populate a subparagraph
        #If the row has not a target header, we add the text to the subparagraph
        if row.name not in header_list:
            full_paragraph_txt += row.text + " "    #We append a space at the end of the row
            full_sub_paragraph_raw.append(row)  #We append the row to the full text
    #At the end of the for, we must save the last paragraph and reset the variables
    text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
    if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
        #All these print are for debug purposes, you can remove them
        print("Still too long..." + str(text_tokens))
        print("Proceding to half split")
        print ("")
        print(filename_sanitized)
        #Since <h6> is the smallest paragraph I found, to further reduce the lenght we split the paragraph in half
        splitted_string = split_string_in_half(full_paragraph_txt)
        #We must repeat the split cicle because otherwise we are going to lose the last paragraph of each document.
        #This could be implemented in a nicer way, separating the splitting loops in their own functions, but for the purpose of this script it's not necessary
        i1 = 1  #We initialize the counter for the first split
        #We iterate on the splitted string
        for split in splitted_string:   
            text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
            if text_tokens > maximum_token_lenght: #If the token count is higher than the maximum lenght we set, we must split the paragraph
                #All these print are for debug purposes, you can remove them
                print("Still still too long..." + str(text_tokens))
                print("Proceding to second half split")
                print ("")
                print(filename_sanitized)
                #If the paragraph is still too long, we split it again
                splitted_string2 = split_string_in_half(split)
                i2 = 1  #We initialize the counter for the second split
                for split2 in splitted_string2:
                    f = open(os.path.join(file_path,filename_sanitized.replace(".txt", "")+"-"+str(i1)+"-"+str(i2)+".txt"), "w", encoding="utf-8")  #Create/open the file
                    f.write(split2)    #Write the variable on the file
                    f.close()   #Close the file
                    i2 += 1 #Increment the counter for the second split
            else:
                f = open(os.path.join(file_path,filename_sanitized.replace(".txt", "")+"-"+str(i1)+".txt"), "w", encoding="utf-8")  #Create/open the file
                f.write(split)  #Write the variable on the file
                f.close()   #Close the file
                i1 += 1 #Increment the counter for the first split
    else:
        f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
        f.write(full_paragraph_txt)    #Write the variable on the file
        f.close()   #Close the file

#File closure could be delegated to its own function, but for the purpose of this script it's not necessary
#A lot of cleanup could be done on this code, but for its limited scope is not necessary. In case webpage structure changes, the code must be updated and maybe this time done properly
        
#Function to split a string in half
def split_string_in_half(s):
    string_structure = []  #List to store the two halves of the string
    midpoint = len(s) // 2  #Find the midpoint of the string
    string_structure.append(s[:midpoint])   #Append the first half of the string
    string_structure.append(s[midpoint:])   #Append the second half of the string
    return string_structure   #Return the list with the two halves of the string

# %% [markdown]
# In the following cell, we are going to iterate each guidelines url, download, parse the webpage and split it files using the above declared functions

# %%
#We declare the chapters to skip, because they do not contain useful informations and they may pollute data
chapters_to_skip = ['introduction', 'methods', 'references', 'conflict-of-interest', 'citation-information']
#Since tokens for LLM are about 4 characters long, we can use this to estimate the maximum lenght of the prompt
token_subdivider = 4        #We use 4 characters as a token lenght
maximum_token_lenght = 4096 #We use 4096 as the maximum token lenght for our model; Must be changed based on your model

#We iterate on each guideline
for url in all_guidelines_url:
    guideline_index_url = website_root + url    #We generate the guideline index url
    html_document = requests.get(guideline_index_url).text #Webpage downloader, output as json
    guideline_soup = BeautifulSoup(html_document, 'html.parser') #Creation of a "soup" object, make easier to navigate the document
    guideline_index = guideline_soup.findAll('li', {'class': 'guideline-chapters__item'})   #Find all the chapters of the specific guideline
    guideline_name = url.rsplit('/', 1)[-1] #We get the guideline name from the url
    guideline_folder = os.path.join(sanitize_filename(folder_guidelines_root), sanitize_filename(guideline_name)) #We generate the folder name
    os.makedirs(guideline_folder, exist_ok=True)  #We create the folder
    #We initialize the lists with the chapter names and urls
    index_name = [] #List with the chapter names
    index_url = []  #List with the chapter urls
    #We iterate on each chapter
    for item in guideline_index:
        index_name.append(item.text)        #We append the chapter name to the list
        index_url.append(item.a['href'])    #We append the chapter url to the list
    number_of_chapters = len(index_name)    #We get the number of chapters
    guideline_content_raw = []  #Chapter content list
    full_page_raw = []  #Full page content list
    #We iterate on each chapter
    for i in range(number_of_chapters):
        guideline_chapter_url = website_root + index_url[i]   #We generate the chapter url
        chapter_title_name_from_url = index_url[i].rsplit('/', 1)[-1] #We get the chapter name from the url
        print("Starting processing: " + chapter_title_name_from_url) #Print for debug purposes
        #We skip the chapters we listed aboce
        if chapter_title_name_from_url not in chapters_to_skip:
            html_document = requests.get(guideline_chapter_url).text #Webpage downloader, output as json
            guideline_chapter_soup = BeautifulSoup(html_document, 'html.parser') #Creation of a "soup" object, make easier to navigate the document
            #The next few steps could be done in a single line, but for clarity purpose I split them
            guideline_text = guideline_chapter_soup.find('article', {'class': 'guideline-text'}) #Find the article tag with the guideline text
            article_text_in_generator = guideline_text.contents #Get the content of the article
            chapter_title = article_text_in_generator[0].text   #Get the chapter title
            chapter_folder = chapter_title.lower().replace(" ", "_") #Generate the chapter folder name
            chapter_folder_path = os.path.join(guideline_folder, sanitize_filename(chapter_folder)) #Generate the chapter folder path
            os.makedirs(chapter_folder_path, exist_ok=True)  #Create the folder
            filename_sanitized = "_PLACEHOLDER_FILENAME_"   #Initialize the filename variable
            definitive_path = "_PLACEHOLDER_PATHNAME_"   #Initialize the definitive path variable
            full_paragraph_raw = []    #Initialize the full paragraph list
            full_paragraph_txt = "_PLACEHOLDER_CONTENT_"    #Initialize the full paragraph text variable
            full_sub_paragraph_txt = "" #Initialize the full subparagraph text variable
            in_paragraph_loop = 0   #Initialize the variable to check if we are populating a subparagraph
            #Loop on the chapter content
            for row in article_text_in_generator:   #Iterating on each row of the chapter
                if row.name == 'h2':    #If it's an header <h2> we can skip it
                    continue
                if row.name == 'h3':    #If it's an header <h3> we must check if we are populating a subparagraph <h4>
                    if in_paragraph_loop == 1: #If we are populating a subparagraph <h4> and we reach an header <h3> we must close the subparagraph and save it
                        text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
                        #Se il testo è troppo lungo, dividiamo con <h4>
                        if text_tokens > maximum_token_lenght:
                            h4_splitter(full_paragraph_raw, chapter_folder_path, token_subdivider, maximum_token_lenght)    #We call the first split function
                            #We reset the variables for a new loop/file
                            full_paragraph_raw = []
                            in_paragraph_loop = 0
                        else:
                            #if the file is short enough, we save it as a single file
                            file_path = chapter_folder_path   #We set the file path
                            os.makedirs(file_path, exist_ok=True)   #Create the folder if it doesn't exist
                            f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Creiamo/apriamo il file
                            f.write(full_paragraph_txt)    #Scriviamo la variabile su file
                            f.close()   #Chiudiamo il file
                            in_paragraph_loop = 0   #Ripristiniamo la variabile per un nuovo loop/file
                    #The if is placed as second, so we don't have to repeat the code in the previous condition
                    #We must check if we are populating a subparagraph <h4> or if we are starting a new paragraph
                    if in_paragraph_loop == 0:
                        filename_sanitized = sanitize_filename(row.text.replace(" ", "_").lower()[:25] + ".txt")  #Sanitize the filename and cut it to the first 25 characters
                        full_paragraph_txt = row.text + ". "  #We append a dot and a space at the end of the row
                        full_paragraph_raw = []    #Initialize the full paragraph list
                        full_paragraph_raw.append(row)  #We append the header to the full text
                        in_paragraph_loop = 1   #We set that we are in a loop to populate a subparagraph    
                else:   #If it's not an header <h3> we must add the text to the paragraph
                    full_paragraph_txt += row.text + " "  #We append a space at the end of the row
                    full_paragraph_raw.append(row)  #We append the row to the full text
            #At the end of the loop we must check if we are populating a subparagraph <h4> and save it
            #We must check the lenght of the praragraph to split it if it's too long
            text_tokens = len(full_paragraph_txt)//token_subdivider #Count the tokens of the chapter subdividing the text by the aproximated token lenght
            #Se il testo è troppo lungo, dividiamo con <h4>
            if text_tokens > maximum_token_lenght:
                h4_splitter(full_paragraph_raw, chapter_folder_path, token_subdivider, maximum_token_lenght)    #We call the first split function
                #We reset the variables for a new loop/file
                full_paragraph_raw = []
                in_paragraph_loop = 0 
            else:
                #if the file is short enough, we save it as a single file
                file_path = chapter_folder_path
                os.makedirs(file_path, exist_ok=True)   #Create the folder if it doesn't exist
                f = open(os.path.join(file_path,filename_sanitized), "w", encoding="utf-8")  #Create/open the file
                f.write(full_paragraph_txt)    #Write the variable on the file
                f.close()   #Close the file
                in_paragraph_loop = 0   #Reset the variable for a new loop/file
        #We skip the chapters we listed aboce
        if chapter_title_name_from_url in chapters_to_skip:
            print("Skipping " + index_url[i].rsplit('/', 1)[-1] + " chapter")

    print("End of guideline: " + guideline_index_url + "\n")
# Out:
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-and-aetiology
# Starting processing: classification-and-staging-systems
# Starting processing: diagnostic-evaluation
# Starting processing: treatment
# Split to h5
# File: 6.2.1._deferred_treatment.txt
# Lenght: 7511
#
# Split to h6
# File: 6.2.1.2._active_surveilla.txt
# Lenght: 5249
#
# Split to h5
# File: 6.2.2._radical_prostatect.txt
# Lenght: 6738
#
# Split to h6
# File: 6.2.2.3._surgical_techniq.txt
# Lenght: 4266
#
# Split to h5
# File: 6.2.3._radiotherapy.txt
# Lenght: 8293
#
# Split to h6
# File: 6.2.3.1._external_beam_ra.txt
# Lenght: 5596
#
# Split to h5
# File: 6.3.5._adjuvant_treatment.txt
# Lenght: 4111
#
# Split to h5
# File: 6.4.5._treatment_of_psa-o.txt
# Lenght: 9606
#
# Split to h6
# File: 6.4.5.1._treatment_of_psa.txt
# Lenght: 6063
#
# Split to h5
# File: 6.7.8._treatment_after_do.txt
# Lenght: 4594
#
# Starting processing: followup
# Starting processing: quality-of-life-outcomes-in-prostate-cancer
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/prostate-cancer
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: pathological-staging-and-classification-systems
# Starting processing: diagnosis
# Starting processing: predicting-disease-recurrence-and-progression
# Starting processing: disease-management
# Starting processing: followup-of-patients-with-nmibc
# Starting processing: patient-reported-outcome-measures-and-quality-indicators-for-nmibc
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/non-muscle-invasive-bladder-cancer
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: staging-and-classification-systems
# Starting processing: diagnosis
# Starting processing: prognosis
# Starting processing: disease-management
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/upper-urinary-tract-urothelial-cell-carcinoma
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: staging-and-classification-systems
# Starting processing: diagnostic-evaluation
# Starting processing: markers
# Starting processing: disease-management
# Split to h5
# File: 7.7.2.1_definitions_‘fit.txt
# Lenght: 4234
#
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/muscle-invasive-and-metastatic-bladder-cancer
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: staging-and-classification-systems
# Starting processing: diagnostic-evaluation-and-staging
# Starting processing: prognosis
# Starting processing: disease-management
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/primary-urethral-carcinoma
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: staging-and-classification-systems
# Starting processing: diagnostic-evaluation
# Starting processing: prognostic-factors
# Starting processing: disease-management
# Split to h5
# File: 7.1.3._radical_and_partia.txt
# Lenght: 4276
#
# Split to h5
# File: 7.1.4._therapeutic_approa.txt
# Lenght: 4538
#
# Split to h5
# File: 7.4.3._immunotherapy.txt
# Lenght: 4377
#
# Split to h5
# File: 7.4.4._therapeutic_strate.txt
# Lenght: 6173
#
# Starting processing: followup-in-rcc
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/renal-cell-carcinoma
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-amp-pathology
# Starting processing: staging-amp-classification-systems
# Starting processing: diagnostic-evaluation
# Starting processing: disease-management
# Starting processing: followup-after-curative-therapy
# Starting processing: rare-adult-para-and-testicular-tumours
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/testicular-cancer
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathology
# Starting processing: staging-and-classification-systems
# Starting processing: diagnostic-evaluation-and-staging
# Starting processing: disease-management
# Split to h5
# File: 6.1.2._treatment_of_invas.txt
# Lenght: 4326
#
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/penile-cancer
#
# Starting processing: introduction-2
# Starting processing: methodology
# Starting processing: male-hypogonadism
# Starting processing: epidemiology-and-prevalence-of-sexual-dysfunction-and-disorders-of-male-reproductive-health
# Starting processing: management-of-erectile-dysfunction
# Starting processing: disorders-of-ejaculation
# Split to h5
# File: 6.2.6._disease_management.txt
# Lenght: 4478
#
# Starting processing: low-sexual-desire-and-male-hypoactive-sexual-desire-disorder
# Starting processing: penile-curvature
# Split to h5
# File: 8.2.3._disease_management.txt
# Lenght: 10587
#
# Split to h6
# File: 8.2.3.1._conservative_tre.txt
# Lenght: 5308
#
# Split to h6
# File: 8.2.3.2._surgical_treatme.txt
# Lenght: 5272
#
# Starting processing: penile-size-abnormalities-and-dysmorphophobia
# Split to h5
# File: 9.3.2._surgical_treatment.txt
# Lenght: 9002
#
# Starting processing: priapism
# Split to h5
# File: 10.1.3._disease_managemen.txt
# Lenght: 6735
#
# Starting processing: male-infertility
# Split to h5
# File: 11.4.3._varicocele.txt
# Lenght: 4638
#
# Starting processing: late-effects-survivorship-and-mens-health
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/sexual-and-reproductive-health
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: diagnosis
# Starting processing: disease-management
# Split to h5
# File: 4.1.4._disease_management.txt
# Lenght: 15068
#
# Split to h6
# File: 4.1.4.1._conservative_man.txt
# Lenght: 4953
#
# Split to h6
# File: 4.1.4.2._pharmacological_.txt
# Lenght: 6541
#
# Split to h5
# File: 4.2.4._disease_management.txt
# Lenght: 20325
#
# Split to h6
# File: 4.2.4.1._conservative_man.txt
# Lenght: 4158
#
# Split to h6
# File: 4.2.4.3._surgical_managem.txt
# Lenght: 14442
#
# Still too long...4582
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...4582
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...4582
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...5328
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...5328
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...5328
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...5427
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...5427
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...5427
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...6607
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...6607
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...6607
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...6974
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...6974
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...6974
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...7856
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...7856
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...7856
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...8139
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8139
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8139
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...8438
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8438
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8438
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...8772
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8772
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8772
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still too long...8943
# Proceding to half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8943
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Still still too long...8943
# Proceding to second half split
#
# 4.2.4.3.2.5._mid-urethral.txt
# Split to h5
# File: 4.5.7._surgical_managemen.txt
# Lenght: 4698
#
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/non-neurogenic-female-luts
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methodology
# Starting processing: definition-epidemiology-aetiology-and-prevention
# Split to h5
# File: 3.3.1._aetiology_and_prev.txt
# Lenght: 5075
#
# Split to h6
# File: 3.3.1._aetiology_and_prev.txt
# Lenght: 5075
#
# Still too long...5075
# Proceding to half split
#
# 3.3.1._aetiology_and_prev.txt
# Still still too long...5075
# Proceding to second half split
#
# 3.3.1._aetiology_and_prev.txt
# Still still too long...5075
# Proceding to second half split
#
# 3.3.1._aetiology_and_prev.txt
# Starting processing: classifications
# Starting processing: diagnostic-evaluation
# Starting processing: disease-management-in-males
# Split to h5
# File: 6.2.1._direct_vision_inte.txt
# Lenght: 4256
#
# Split to h5
# File: 6.3.1._the_role_of_urethr.txt
# Lenght: 4578
#
# Split to h5
# File: 6.3.2._urethroplasty_for_.txt
# Lenght: 5318
#
# Split to h5
# File: 6.3.5._posterior_urethra.txt
# Lenght: 10567
#
# Split to h6
# File: 6.3.5.1._non-traumatic_po.txt
# Lenght: 6740
#
# Starting processing: disease-management-in-females
# Starting processing: disease-management-in-transgender-patients
# Starting processing: tissue-transfer
# Starting processing: perioperative-care-of-urethral-surgery
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/urethral-strictures
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-aetiology-and-pathophysiology
# Starting processing: diagnostic-evaluation
# Starting processing: disease-management
# Split to h5
# File: 5.2.7._combination_therap.txt
# Lenght: 4608
#
# Split to h5
# File: 5.3.2._enucleation_of_the.txt
# Lenght: 7031
#
# Split to h5
# File: 5.6.5._surgical_treatment.txt
# Lenght: 4935
#
# Starting processing: followup
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/management-of-non-neurogenic-male-luts
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methodology
# Starting processing: epidemiology-aetiology-and-pathophysiology
# Split to h5
# File: 3.1.5._risk_factors_and_u.txt
# Lenght: 5176
#
# Split to h5
# File: 3.2.5._risk_factors_and_u.txt
# Lenght: 6151
#
# Starting processing: diagnostic-evaluation
# Starting processing: management
# Split to h5
# File: 5.2.1._drugs_for_chronic_.txt
# Lenght: 5478
#
# Split to h6
# File: 5.2.1.2._comparisons_of_a.txt
# Lenght: 5168
#
# Still too long...5168
# Proceding to half split
#
# 5.2.1.2._comparisons_of_a.txt
# Still still too long...5168
# Proceding to second half split
#
# 5.2.1.2._comparisons_of_a.txt
# Still still too long...5168
# Proceding to second half split
#
# 5.2.1.2._comparisons_of_a.txt
# Starting processing: evaluation-of-treatment-results
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/chronic-pelvic-pain
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: the-guideline
# Split to h5
# File: 3.3.5._disease_management.txt
# Lenght: 4353
#
# Split to h5
# File: 3.16.2._specific_procedur.txt
# Lenght: 4539
#
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/urological-infections
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: the-guideline
# Split to h5
# File: 3.4.2._non-invasive_conse.txt
# Lenght: 5656
#
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/neuro-urology
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: guidelines
# Starting processing: metabolic-evaluation-and-recurrence-prevention
# Starting processing: followup-of-urinary-stones
# Starting processing: bladder-stones
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/urolithiasis
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: the-guideline
# Split to h5
# File: 3.13.4._management.txt
# Lenght: 6376
#
# Split to h5
# File: 3.16.4._management.txt
# Lenght: 5132
#
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/paediatric-urology
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: epidemiology-classification-amp-general-managemnet-principals
# Starting processing: urogenital-trauma-guidelines
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/urological-trauma
#
# Starting processing: introduction
# Skipping introduction chapter
# Starting processing: methods
# Skipping methods chapter
# Starting processing: the-guideline
# Split to h5
# File: 3.1.5._surgical_approache.txt
# Lenght: 5482
#
# Split to h5
# File: 3.1.7._recipient_complica.txt
# Lenght: 4759
#
# Split to h5
# File: 3.1.10._immunosuppression.txt
# Lenght: 5867
#
# Starting processing: references
# Skipping references chapter
# Starting processing: conflict-of-interest
# Skipping conflict-of-interest chapter
# Starting processing: citation-information
# Skipping citation-information chapter
# End of guideline: https://uroweb.org/guidelines/renal-transplantation

# %% [markdown]
# Once extracted, the text must be cleaned.
# We do this in two separate step to allow editing in a non destructive way, allowing to modify the cleaning parameters without the need of redownloading everything.

# %%
import cleantext
import re
import glob
import os
from pathvalidate import sanitize_filename

#Define the path to the files
txt_folder_path = sanitize_filename(folder_guidelines_root) #Folder path of the guidelines, inherited from the previous functions
#Join the path of rag_sources and the guidelines folder
processed_file_folder = "rag_sources" #Folder path for the processed files
processed_file_path = os.path.join(processed_file_folder, txt_folder_path)

#Define the function to clean the text
def txt_processer (file_path):    
    extracted_text = open(file_path, "r", encoding="utf-8").read()  #Open the file and read the content
    extracted_text_without_citations = re.sub(r'\[\d+(,\d+)*\]', '', extracted_text) #Remove the citations numbers
    cleaned_text = cleantext.clean(
            extracted_text_without_citations,
            clean_all=False,    #If True, it will set all the others parameters to True
            extra_spaces=True,  #Remove extra white spaces
            stemming=False,     #Perform stemming
            stopwords=True,     #Removal of selected language stopwords
            stp_lang='english', #Stopwords language
            lowercase=True,     #Lowercase all the text
        )
    return cleaned_text

#Create the folder if it doesn't exist
os.makedirs(processed_file_path, exist_ok=True)
#Iterating on each file in the main directory
for filename in glob.iglob(txt_folder_path + "/**/**.txt", recursive=True):
    print(filename)
    #os.path.split splits the path in two parts, the folders [0] and the file [1]
    document_file_name = os.path.split(filename)[1] #Get the file name, including the extension
    #We define the folder path of the file replacing the txt_folder_path with processed_file_path
    processed_folder_path = os.path.split(filename)[0].replace(txt_folder_path, processed_file_path)
    #We create the folder if it doesn't exist
    os.makedirs(processed_folder_path, exist_ok=True)
    cleaned_text = txt_processer(filename) #Invoke the function to clean the text
    file = open(os.path.join(processed_folder_path, document_file_name) , "w", encoding="utf-8")  #Create/open the file, we replace the folder path with the processed one
    file.writelines(cleaned_text)   #Write the cleaned text on the file
    file.close()    #Close the file

print("Processed: " + filename + "\n")
# Out:
# guidelines\chronic-pelvic-pain\2._methodology\2.1._methods.txt
# guidelines\chronic-pelvic-pain\2._methodology\2.2._review.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.3._abdominal_aspects_of.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.4._summary_of_evidence_.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.1._incidence.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.2._prevalence.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.3._influence_on_quali.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.4._costs.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1._chronic_visceral_pai.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.5._risk_fac\3.1.5.1._risk_factors.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.5._risk_fac\3.1.5.2._underlying_cause.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.1._chronic_vi\3.1.5._risk_fac\3.1.5.3._clinical_paradig.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.1._incidence.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.2._prevalence.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.3._influence_on_quali.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.4._costs.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.1._primary_prostate.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.2._primary_bladder_.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.3._primary_scrotal_.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.4._primary_urethral.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.5._primary_vaginal_.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.6._chronic_pelvic_p.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.7._chronic_post-sur.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5.8._associated_condi.txt
# guidelines\chronic-pelvic-pain\3._epidemiology_aetiology_and_pathophysiology\3.2._pelvic_pai\3.2.5._risk_fac\3.2.5._risk_factors_and_u.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.2._supplemental_evaluat.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.3._diagnostic_algorithm.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.4._other_painful_condit.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.5._summary_of_evidence_.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.1._general_ev\4.1.1._history.txt
# guidelines\chronic-pelvic-pain\4._diagnostic_evaluation\4.1._general_ev\4.1.2._physical_evaluatio.txt
# guidelines\chronic-pelvic-pain\5._management\5.1._conservative_managem.txt
# guidelines\chronic-pelvic-pain\5._management\5.4._summary_of_evidence_.txt
# guidelines\chronic-pelvic-pain\5._management\5.2._pharmacolo\5.2.2._analgesics.txt
# guidelines\chronic-pelvic-pain\5._management\5.2._pharmacolo\5.2.1._drugs_fo\5.2.1.1._mechanisms_of_ac.txt
# guidelines\chronic-pelvic-pain\5._management\5.2._pharmacolo\5.2.1._drugs_fo\5.2.1._drugs_for_chronic_.txt
# guidelines\chronic-pelvic-pain\5._management\5.2._pharmacolo\5.2.1._drugs_fo\5.2.1.2._compar\5.2.1.2._comparisons_of_a-1-1.txt
# guidelines\chronic-pelvic-pain\5._management\5.2._pharmacolo\5.2.1._drugs_fo\5.2.1.2._compar\5.2.1.2._comparisons_of_a-1-2.txt
# guidelines\chronic-pelvic-pain\5._management\5.3._further_ma\5.3.1._nerve_blocks.txt
# guidelines\chronic-pelvic-pain\5._management\5.3._further_ma\5.3.2._neuromodulation.txt
# guidelines\chronic-pelvic-pain\5._management\5.3._further_ma\5.3.3._surgery.txt
# guidelines\chronic-pelvic-pain\6._evaluation_of_treatment_results\6.1._evaluation_of_treatm.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.1._medical_history.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.10._imaging.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.11._urethrocystoscopy.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.12._urodynamics.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.13._non-invasive_tests_.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.14._novel_assessment.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.2._symptom_score_questi.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.3._frequency_volume_cha.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.4._physical_examination.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.5._urinalysis.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.6._prostate-specific_an.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.7._renal_function_measu.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.8._post-void_residual_u.txt
# guidelines\management-of-non-neurogenic-male-luts\4._diagnostic_evaluation\4.9._uroflowmetry.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.1._conservative_treatme.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.4._patient_selection_fo.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.1._α1-adrenoceptor_an.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.2.5_α-reductase_inhib.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.3._muscarinic_recepto.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.4._beta-3_agonist.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.5._phosphodiesterase_.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.6._plant_extracts_–_p.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.7._combinat\5.2.7.1._α1-blockers_+_5α.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.7._combinat\5.2.7.2._α1-blockers_+_mu.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.7._combinat\5.2.7.3.α1-blockers_+_bet.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.2._pharmacolo\5.2.7._combinat\5.2.7.4.α1-blockers_+_pho.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.1._resection_of_the_p.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.3._vaporisation_of_th.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.4._alternative_ablati.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.5._non-ablative_techn.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3._surgical_treatment_o.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.1._open_prostatecto.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.2._bipolar_transure.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.3._holmium_laser_en.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.4._thuliumyttrium-.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.5._diode_laser_enuc.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.3._surgical_t\5.3.2._enucleat\5.3.2.6._enucleation_tech.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.5._management\5.5.1._diagnostic_assessm.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.5._management\5.5.2._medical_conditions.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.5._management\5.5.3._treatment_for_noct.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.5._management\5.5._management_of_noctur.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.1._epidemiology_and_p.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.2._diagnostic_evaluat.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.3._conservative_treat.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.4._pharmacological_ma.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.6._surgical_treatment.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6._management_of_male_u.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.5._surgical\5.6.5.1._bulking_agents_i.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.5._surgical\5.6.5.2._male_slings.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.6._management\5.6.5._surgical\5.6.5.3._compression_devi.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.1._epidemiology_and_p.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.2._diagnostic_evaluat.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.3._conservative_manag.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.4._pharmacological_ma.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.5._surgical_treatment.txt
# guidelines\management-of-non-neurogenic-male-luts\5._disease_management\5.7._management\5.7.6._follow-up.txt
# guidelines\management-of-non-neurogenic-male-luts\6._follow_up\6.1._watchful_waiting_(be.txt
# guidelines\management-of-non-neurogenic-male-luts\6._follow_up\6.2._medical_treatment.txt
# guidelines\management-of-non-neurogenic-male-luts\6._follow_up\6.3._surgical_treatment.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\3._epidemiology_aetiology_and_pathology\3.1._epidemiology.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\3._epidemiology_aetiology_and_pathology\3.2._aetiology.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\3._epidemiology_aetiology_and_pathology\3.3._pathology.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\4._staging_and_classification_systems\4.1._pathological_staging.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\4._staging_and_classification_systems\4.2._tumour,_node,_metast.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\5._diagnostic_evaluation\5.1._primary_diagnosis.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\5._diagnostic_evaluation\5.2._imaging_for_staging_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\5._diagnostic_evaluation\5.3._muscle-invasive_and_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\6._markers\6.1._introduction.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\6._markers\6.2._prognostic_markers.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\6._markers\6.3._predictive_markers.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\6._markers\6.4._conclusion.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\6._markers\6.5._summary_of_evidence_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.1._neoadjuvant_therapy.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.2._pre-_and_post-operat.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.4._palliative_and_salva.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.6._adjuvant_therapy.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.8._quality_of_life.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.1._removal_of_the_tum.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.10._summary_of_eviden.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.2._radical_cystectomy.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.3._radical_cystectomy.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.4._lymphadenectomy_r.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.5._robotic-assisted_l.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.6._urinary_diversion_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.7._morbidity_and_mort.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.8._survival.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.3._radical_su\7.3.9._impact_of_hospital.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.5._bladder-sp\7.5.1._transurethral_rese.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.5._bladder-sp\7.5.2._external_beam_radi.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.5._bladder-sp\7.5.3._chemotherapy.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.5._bladder-sp\7.5.4._trimodality_bladde.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.1._introduction.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.2._first-line_systemi.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.3._further-line_syste.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.4._integration_of_oth.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.5._current_status_of_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.6._special_situations.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.7._treatment_of_patie.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.8._summary_treatment.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.9._summary_of_evidenc.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.2.1_definit\7.7.2.1._first-line_chemo.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.2.1_definit\7.7.2.1_definitions_‘fit.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.2.1_definit\7.7.2.2._first_line_thera.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\7._disease_management\7.7._metastatic\7.7.2.1_definit\7.7.2.3._results_of_other.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.1._follow-up_in_muscle_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.2._site_of_recurrence.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.3._time_schedule_for_su.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.4._follow-up_of_functio.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.5._summary_of_evidence_.txt
# guidelines\muscle-invasive-and-metastatic-bladder-cancer\8._follow_up\8.6._eau-esmo_consensus_s.txt
# guidelines\neuro-urology\3._the_guideline\3.1._epidemiology,_aetiol.txt
# guidelines\neuro-urology\3._the_guideline\3.2._classification_syste.txt
# guidelines\neuro-urology\3._the_guideline\3.5._urinary_tract_infect.txt
# guidelines\neuro-urology\3._the_guideline\3.6._sexual_function_and_.txt
# guidelines\neuro-urology\3._the_guideline\3.7._follow-up.txt
# guidelines\neuro-urology\3._the_guideline\3.8._conclusions.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.1._introduction.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.2._classification_sys.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.3._timing_of_diagnosi.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.4._patient_history.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.5._patient_quality_of.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.6._physical_examinati.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.7._urodynamics.txt
# guidelines\neuro-urology\3._the_guideline\3.3._diagnostic\3.3.8._renal_function.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.1._introduction.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.3._surgical_treatment.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.2._non-inva\3.4.2.1._assisted_bladder.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.2._non-inva\3.4.2.2._neuro-urological.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.2._non-inva\3.4.2.3._drug_treatment.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.2._non-inva\3.4.2.4._summary_of_evide.txt
# guidelines\neuro-urology\3._the_guideline\3.4._disease_ma\3.4.2._non-inva\3.4.2.5._minimally_invasi.txt
# guidelines\non-muscle-invasive-bladder-cancer\3._epidemiology_and_aetiology\3.1._epidemiology.txt
# guidelines\non-muscle-invasive-bladder-cancer\3._epidemiology_and_aetiology\3.2._aetiology.txt
# guidelines\non-muscle-invasive-bladder-cancer\3._epidemiology_and_aetiology\3.3._summary_of_evidence_.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.1._definition_of_non-mu.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.10._summary_of_evidence.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.2._tumour,_node,_metast.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.3._t1_subclassification.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.4._lymphovascular_invas.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.5._histological_grading.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.6._carcinoma_in_situ.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.7._inter-_and_intra-obs.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.8._subtypes_of_urotheli.txt
# guidelines\non-muscle-invasive-bladder-cancer\4._pathological_staging,_grading_and_classification_systems\4.9._tumour_markers_and_m.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.1._patient_history.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.10._transurethral_resec.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.11._endoscopic_biopsies.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.12._new_methods_of_tumo.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.13._second_resection_(s.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.14._pathology_report.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.15._summary_of_evidence.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.2._signs_and_symptoms.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.3._physical_examination.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.4._imaging.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.5._urinary_cytology.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.6._urinary_molecular_ma.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.7._potential_applicatio.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.8._cystoscopy.txt
# guidelines\non-muscle-invasive-bladder-cancer\5._diagnosis\5.9._summary_of_evidence_.txt
# guidelines\non-muscle-invasive-bladder-cancer\6._predicting_disease_recurrence_and_progression\6.1._tat1_tumours.txt
# guidelines\non-muscle-invasive-bladder-cancer\6._predicting_disease_recurrence_and_progression\6.2._primary_carcinoma_in.txt
# guidelines\non-muscle-invasive-bladder-cancer\6._predicting_disease_recurrence_and_progression\6.3._patient_stratificati.txt
# guidelines\non-muscle-invasive-bladder-cancer\6._predicting_disease_recurrence_and_progression\6.4._summary_of_evidence_.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.1._counselling_of_smoki.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.10._guidelines_for_adju.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.11._guidelines_for_the_.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.2._office-based_fulgura.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.3._active_surveillance.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.5._intravesical_chemoab.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.6._radical_cystectomy_f.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.7._primary_treatment_by.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.8._multidisciplinary_tu.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.9._treatment_of_failure.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4.1._post-operative_irr.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4.2._intravesical_chemo.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4.3._intravesical_bacil.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4.4._combination_therap.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4.5._specific_aspects_o.txt
# guidelines\non-muscle-invasive-bladder-cancer\7._disease_management\7.4._adjuvant_i\7.4._adjuvant_intravesica.txt
# guidelines\non-muscle-invasive-bladder-cancer\8._follow_up\8.1._intravesical_surveil.txt
# guidelines\non-muscle-invasive-bladder-cancer\8._follow_up\8.2._summary_of_evidence_.txt
# guidelines\non-muscle-invasive-bladder-cancer\9._patient_reported_outcome_measures_and_quality_indicators_for_nmibc\9.1._proms_and_prems_in_n.txt
# guidelines\non-muscle-invasive-bladder-cancer\9._patient_reported_outcome_measures_and_quality_indicators_for_nmibc\9.2._quality_indicators_(.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.1._history_and_physical.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.2._patient_questionnair.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.3._bladder_diaries.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.4._urinalysis_and_urina.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.5._post-void_residual_v.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.6._urodynamics.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.7._pad_testing.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.8._imaging.txt
# guidelines\non-neurogenic-female-luts\3._diagnosis\3.9._urinary_biomarkers_a.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.3._mixed_urinary_incont.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.5._follow-up.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.3._surgical_managem.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.1._addressing_ass.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.2.1._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.2._adjustment_of_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.3.1._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.3._urinary_contai.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4.1._caffeine_int.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4.2._fluid_intake.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4.3._weight_loss.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4.4._smoking_cess.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4.5._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.4._lifestyle_inte.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.1._prompted_voi.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.2._bladder_trai.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.3._pelvic_floor.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.4._electrical_s.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.5._acupuncture.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5.6._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1.5._behavioural_an.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.1._conser\4.1.4.1._conservative_man.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1.1._comparison_o.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1.2.1._anticholin.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1.2._anticholiner.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1.3._anticholiner.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1.4._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.1._anticholinergi.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.2.1._beta-3_agoni.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.2.2._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.2._beta-3_agonist.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.3.1._applicabilit.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.3.2._anticholiner.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.3.3._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.3._anticholinergi.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.4.1._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.4._oestrogens.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.1._overactive\4.1.4._disease_\4.1.4.2._pharma\4.1.4.2.5._placebo_and_no.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.5._follow-up.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.2._pharmacological_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.1.1._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.1._obesity_and_we.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.2._urinary_contai.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.1._efficacy_of_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.2._efficacy_of_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.3._long-term_ef.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.4._efficacy_of_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.5._efficacy_of_.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.6._composite_tr.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3.7._summary_of_e.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.3._pelvic_floor_m.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.4._electromagneti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.1._conser\4.2.4.1.5._electroacupunc.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.1.1._shared_decis.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.1.2._recommendati.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.1._general_consid.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.1._open-_and_la.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.2._autologous_s.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.3._urethral_bul.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.4._laser_treatm.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.5._mid-urethral-1-1.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2.5._mid-urethral-1-2.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.2._stress_uri\4.2.4._disease_\4.2.4.3._surgic\4.2.4.3.2._surgery_for_wo.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4.4._disease_management.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4.5._follow-up.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.4._underactiv\4.4._underactive_bladder.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.1._introduction.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.2._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.3._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.4._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.5._disease_management.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.6._pharmacological_ma.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.8._follow-up.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.1._intra-sphincteri.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.10._summary_of_evid.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.2._sacral_nerve_sti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.3._pelvic_organ_pro.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.4._urethral_dilatat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.5._urethrotomy.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.6._bladder_neck_inc.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.7._urethroplastyur.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.8._urethrolysis.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.5._bladder_ou\4.5.7._surgical\4.5.7.9._removalexcision.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6.4._disease_management.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6.5._follow-up.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.6._nocturia\4.6._nocturia.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.7._pelvic_org\4.7.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.7._pelvic_org\4.7.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.7._pelvic_org\4.7.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.7._pelvic_org\4.7.4._disease_management.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.7._pelvic_org\4.7.5._summary_of_evidenc.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.8._urinary_fi\4.8.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.8._urinary_fi\4.8.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.8._urinary_fi\4.8.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.8._urinary_fi\4.8.4._management_of_fist.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.8._urinary_fi\4.8._urinary_fistula.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9.1._epidemiology,_aeti.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9.2._classification.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9.3._diagnostic_evaluat.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9.4._disease_management.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9.5._summary_of_evidenc.txt
# guidelines\non-neurogenic-female-luts\4._disease_management\4.9._urethral_d\4.9._urethral_diverticulu.txt
# guidelines\paediatric-urology\3._the_guideline\3.1._phimosis_and_other_a.txt
# guidelines\paediatric-urology\3._the_guideline\3.12._monosymptomatic_noc.txt
# guidelines\paediatric-urology\3._the_guideline\3.14._dilatation_of_the_u.txt
# guidelines\paediatric-urology\3._the_guideline\3.17._obstructive_patholo.txt
# guidelines\paediatric-urology\3._the_guideline\3.21._emergencies_in_paed.txt
# guidelines\paediatric-urology\3._the_guideline\3.24._basic_principles_of.txt
# guidelines\paediatric-urology\3._the_guideline\3.3._testicular_tumours_i.txt
# guidelines\paediatric-urology\3._the_guideline\3.4._fertility_preservati.txt
# guidelines\paediatric-urology\3._the_guideline\3.5._hydrocele.txt
# guidelines\paediatric-urology\3._the_guideline\3.6._acute_scrotum.txt
# guidelines\paediatric-urology\3._the_guideline\3.8._congenital_penile_cu.txt
# guidelines\paediatric-urology\3._the_guideline\3.9._varicocele_in_childr.txt
# guidelines\paediatric-urology\3._the_guideline\3.10._urinary_t\3.10.1._epidemiology,_aet.txt
# guidelines\paediatric-urology\3._the_guideline\3.10._urinary_t\3.10.2._classification_sy.txt
# guidelines\paediatric-urology\3._the_guideline\3.10._urinary_t\3.10.3._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.10._urinary_t\3.10.4._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.10._urinary_t\3.10.5._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.11._day-time_\3.11.1._terminology,_clas.txt
# guidelines\paediatric-urology\3._the_guideline\3.11._day-time_\3.11.2._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.11._day-time_\3.11.3._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.11._day-time_\3.11.4._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.1._epidemiology,_aet.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.2._classification_sy.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.3._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.5._follow-up.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.6._self-organisation.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.7._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.1._early_managemen.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.2._medical_therapy.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.3._management_of_f.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.4._urinary_tract_i.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.5._sexuality.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.6._bladder_augment.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.7._bladder_outlet_.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.8._catheterisable_.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4.9._continent_and_i.txt
# guidelines\paediatric-urology\3._the_guideline\3.13._managemen\3.13.4._managem\3.13.4._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.15._vesicoure\3.15.1._epidemiology,_aet.txt
# guidelines\paediatric-urology\3._the_guideline\3.15._vesicoure\3.15.2._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.15._vesicoure\3.15.3._disease_managemen.txt
# guidelines\paediatric-urology\3._the_guideline\3.15._vesicoure\3.15.4._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.15._vesicoure\3.15._vesicoureteric_refl.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.1._epidemiology,_aet.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.2._classification_sy.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.3._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.5._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.4._managem\3.16.4.1._extracorporeal_.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.4._managem\3.16.4.2._percutaneous_ne.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.4._managem\3.16.4.3._ureterorenoscop.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.4._managem\3.16.4.4._open_or_laparos.txt
# guidelines\paediatric-urology\3._the_guideline\3.16._urinary_s\3.16.4._managem\3.16.4._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.1._introduction.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.2._international_con.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.3._current_classific.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.4._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.5._gender_assignment.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.6._risk_of_tumour_de.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.7._quality_of_life.txt
# guidelines\paediatric-urology\3._the_guideline\3.18._disorders\3.18.8._recommendations_f.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.1._posterior_urethra.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.2._classification_sy.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.3._diagnostic_evalua.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.4._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.5._follow-up.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19.6._summary_of_eviden.txt
# guidelines\paediatric-urology\3._the_guideline\3.19._congenita\3.19._congenital_lower_ur.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.1._background.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.2._classification.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.3._diagnostic_evaluat.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.4._management.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.5._undescended_testes.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.6._undescended_testes.txt
# guidelines\paediatric-urology\3._the_guideline\3.2._management\3.2.7._summary_of_evidenc.txt
# guidelines\paediatric-urology\3._the_guideline\3.20._rare_cond\3.20.1._urachal_remnants.txt
# guidelines\paediatric-urology\3._the_guideline\3.20._rare_cond\3.20.2._papillary_tumours.txt
# guidelines\paediatric-urology\3._the_guideline\3.20._rare_cond\3.20.3._penile_rare_condi.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22.1._paediatric_renal_.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22.2._paediatric_ureter.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22.3._paediatric_bladde.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22.4._paediatric_urethr.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22.5._urosepsis.txt
# guidelines\paediatric-urology\3._the_guideline\3.22._paediatri\3.22._paediatric_urologic.txt
# guidelines\paediatric-urology\3._the_guideline\3.23._peri-oper\3.23.1._pre-operative_fas.txt
# guidelines\paediatric-urology\3._the_guideline\3.23._peri-oper\3.23.2._post-operative_pa.txt
# guidelines\paediatric-urology\3._the_guideline\3.23._peri-oper\3.23.3._antibiotics_manag.txt
# guidelines\paediatric-urology\3._the_guideline\3.23._peri-oper\3.23.4._thromboprophylaxi.txt
# guidelines\paediatric-urology\3._the_guideline\3.23._peri-oper\3.23.5._premedication_man.txt
# guidelines\paediatric-urology\3._the_guideline\3.7._hypospadia\3.7.1._epidemiology,_aeti.txt
# guidelines\paediatric-urology\3._the_guideline\3.7._hypospadia\3.7.2._risk_factors.txt
# guidelines\paediatric-urology\3._the_guideline\3.7._hypospadia\3.7.3._classification_sys.txt
# guidelines\paediatric-urology\3._the_guideline\3.7._hypospadia\3.7.4._diagnostic_evaluat.txt
# guidelines\paediatric-urology\3._the_guideline\3.7._hypospadia\3.7.5._management.txt
# ...
# guidelines\urethral-strictures\5._diagnostic_evaluation\5.2._physical_e\5.2._physical_examination.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.1._conservative_options.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.2._single_dilatation.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.3._post-dilatationdi.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2._endoluminal_treatmen.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.1._direct_v\6.2.1.1._indications_of_“.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.1._direct_v\6.2.1.2._indications_of_“.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.1._direct_v\6.2.1.3._complications_of.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.2._endolumina\6.2.1._direct_v\6.2.1._direct_vision_inte.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.3._urethroplasty_for_.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.4._perineal_urethrost.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.1._staged_augmentat.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.2._single-stage_aug.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.3._anastomotic_uret.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.4._specific_conside.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.5._specific_conside.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1.6._distal_urethral_.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.1._the_role\6.3.1._the_role_of_urethr.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.2._urethrop\6.3.2.1.“short”_bulbar_st.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.2._urethrop\6.3.2.2.“longer”_bulbar_s.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.2._urethrop\6.3.2.3._staged_urethropl.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.2._urethrop\6.3.2.4._management_of_re.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.2._post-traumatic_p.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.1._treatment_of_n.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.2.1._dilatation_o.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.2.2._endoscopic_i.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.2.3._post-dilatat.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.3.1._redo_vesico-.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.3.2._posterior_st.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.3.3._radiationhi.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.3._lower_urinary_.txt
# guidelines\urethral-strictures\6._disease_management_in_males\6.3._open_repai\6.3.5._posterio\6.3.5.1._non-tr\6.3.5.1.4._extirpative_su.txt
# guidelines\urethral-strictures\7._disease_management_in_females\7.1._signs_and_symptoms_o.txt
# guidelines\urethral-strictures\7._disease_management_in_females\7.2._diagnosis_of_female_.txt
# guidelines\urethral-strictures\7._disease_management_in_females\7.3._treatment_of_female_.txt
# guidelines\urethral-strictures\8._disease_management_in_transgender_patients\8.1._treatment_of_strictu.txt
# guidelines\urethral-strictures\8._disease_management_in_transgender_patients\8.2._peri-operative_care_.txt
# guidelines\urethral-strictures\8._disease_management_in_transgender_patients\8.3._strictures_in_trans_.txt
# guidelines\urethral-strictures\9._tissue_transfer\9.1._comparison_of_grafts.txt
# guidelines\urethral-strictures\9._tissue_transfer\9.2._comparison_of_differ.txt
# guidelines\urethral-strictures\9._tissue_transfer\9.3._comparison_of_differ.txt
# guidelines\urethral-strictures\9._tissue_transfer\9.4._tissue_engineered_gr.txt
# guidelines\urethral-strictures\9._tissue_transfer\9.5._management_of_oral_c.txt
# guidelines\urolithiasis\3._guidelines\3.1._prevalence,_aetiolog.txt
# guidelines\urolithiasis\3._guidelines\3.2._classification_of_st.txt
# guidelines\urolithiasis\3._guidelines\3.3._diagnostic_evaluatio.txt
# guidelines\urolithiasis\3._guidelines\3.5._radiation_exposure_a.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.1._renal_colic.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.10._specific_stone_ma.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.11._laparoscopy_and_o.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.12._steinstrasse.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.13._management_of_pat.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.14._management_of_spe.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.15._management_of_sto.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.2._management_of_seps.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.3._medical_expulsive_.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.4._chemolysis.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.5._extracorporeal_sho.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.6._ureteroscopy_(retr.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.7._percutaneous_nephr.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.8._general_recommenda.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4.9._specific_stone_man.txt
# guidelines\urolithiasis\3._guidelines\3.4._disease_ma\3.4._disease_management.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.10. _2,8-dihydroxyanden.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.11._drug-induced_stones.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.12._matrix_stones.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.13._unknown_stone_compo.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.2._general_consideratio.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.3._stone-specific_metab.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.4._calcium_oxalate_ston.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.5._calcium_phosphate_st.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.6._disorders_and_diseas.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.7._uric_acid_and_ammoni.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.8._struvite_and_infecti.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4.9._cystine_stones.txt
# guidelines\urolithiasis\4._metabolic_evaluation_and_recurrence_preventionprevention\4._metabolic_evaluation_a.txt
# guidelines\urolithiasis\6._bladder_stones\6.1._prevalence,_aetiolog.txt
# guidelines\urolithiasis\6._bladder_stones\6.2._presentation.txt
# guidelines\urolithiasis\6._bladder_stones\6.3._diagnostic_evaluatio.txt
# guidelines\urolithiasis\6._bladder_stones\6.5._bladder_stones_follo.txt
# guidelines\urolithiasis\6._bladder_stones\6.6._summary_of_evidence_.txt
# guidelines\urolithiasis\6._bladder_stones\6.4._disease_ma\6.4.1._conservative_treat.txt
# guidelines\urolithiasis\6._bladder_stones\6.4._disease_ma\6.4.2._medical_management.txt
# guidelines\urolithiasis\6._bladder_stones\6.4._disease_ma\6.4.3._bladder_stone_inte.txt
# guidelines\urolithiasis\6._bladder_stones\6.4._disease_ma\6.4.4._treatment_for_blad.txt
# guidelines\urolithiasis\6._bladder_stones\6.4._disease_ma\6.4.5._special_situations.txt
# guidelines\urological-infections\3._the_guideline\3.1._classification.txt
# guidelines\urological-infections\3._the_guideline\3.10._urethritis.txt
# guidelines\urological-infections\3._the_guideline\3.11._bacterial_prostatit.txt
# guidelines\urological-infections\3._the_guideline\3.12._acute_infective_epi.txt
# guidelines\urological-infections\3._the_guideline\3.13._fournier’s_gangrene.txt
# guidelines\urological-infections\3._the_guideline\3.14._management_of_human.txt
# guidelines\urological-infections\3._the_guideline\3.15._genitourinary_tuber.txt
# guidelines\urological-infections\3._the_guideline\3.2._antimicrobial_stewar.txt
# guidelines\urological-infections\3._the_guideline\3.4._uncomplicated_cystit.txt
# guidelines\urological-infections\3._the_guideline\3.6._uncomplicated_pyelon.txt
# guidelines\urological-infections\3._the_guideline\3.7._complicated_utis.txt
# guidelines\urological-infections\3._the_guideline\3.9._urosepsis.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.1._general_principle.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.3._summary_of_eviden.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.1._urodynamics.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.2._cystoscopy.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.3._interventions_f.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.4._transurethral_r.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.5._transurethral_r.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.6._midurethral_sli.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.7._renal_tumour_ab.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2.8._prostate_biopsy.txt
# guidelines\urological-infections\3._the_guideline\3.16._peri-proc\3.16.2._specifi\3.16.2._specific_procedur.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.1._background.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.2._epidemiology,_aeti.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.3._diagnostic_evaluat.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.4._evidence_summary.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.6._follow-up.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.7._summary_of_evidenc.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.1._patients_without.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.2._patients_with_ab.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.3._pregnant_women.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.4._patients_with_id.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.5._prior_to_urologi.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.6._prior_to_orthopa.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.7._prior_to_cardiov.txt
# guidelines\urological-infections\3._the_guideline\3.3._asymptomat\3.3.5._disease_\3.3.5.8._pharmacological_.txt
# guidelines\urological-infections\3._the_guideline\3.5._recurrent_\3.5.1._introduction.txt
# guidelines\urological-infections\3._the_guideline\3.5._recurrent_\3.5.2._diagnostic_evaluat.txt
# guidelines\urological-infections\3._the_guideline\3.5._recurrent_\3.5.3._disease_management.txt
# guidelines\urological-infections\3._the_guideline\3.5._recurrent_\3.5.4._summary_of_evidenc.txt
# guidelines\urological-infections\3._the_guideline\3.8._catheter-a\3.8.1._introduction.txt
# guidelines\urological-infections\3._the_guideline\3.8._catheter-a\3.8.2._epidemiology,_aeti.txt
# guidelines\urological-infections\3._the_guideline\3.8._catheter-a\3.8.3._diagnostic_evaluat.txt
# guidelines\urological-infections\3._the_guideline\3.8._catheter-a\3.8.4._disease_management.txt
# guidelines\urological-trauma\3._epidemiology_classification_general_management_principals\3.1._definition_and_epide.txt
# guidelines\urological-trauma\3._epidemiology_classification_general_management_principals\3.2._classification_of_tr.txt
# guidelines\urological-trauma\3._epidemiology_classification_general_management_principals\3.3._general_management_p.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.2._ureteral_trauma.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.3._bladder_trauma.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.1._epidemiology,_aeti.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.2._evaluation.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.3._imaging_criteria_.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.4._disease_management.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.5._follow-up.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.6._iatrogenic_renal_i.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.7._summary_of_evidenc.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.1._renal_trau\4.1.8._treatment_algorith.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.4._urethral_t\4.4.1._epidemiology,_aeti.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.4._urethral_t\4.4.2._evaluation.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.4._urethral_t\4.4.3._disease_management.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.4._urethral_t\4.4.4._summary_of_evidenc.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.4._urethral_t\4.4.5._treatment_algorith.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.1._epidemiology,_aeti.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.2._diagnostic_evaluat.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.3._imaging.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.4._disease_management.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.5._complications.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.6._follow-up.txt
# guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.7._summary_of_evidenc.txt
# Processed: guidelines\urological-trauma\4._urogenital_trauma_guidelines\4.5._genital_tr\4.5.7._summary_of_evidenc.txt
